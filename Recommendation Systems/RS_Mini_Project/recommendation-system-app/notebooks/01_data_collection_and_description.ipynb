# %% [markdown]
# # Data Collection and Description
#
# In this notebook, we will cover the data collection process and provide a detailed description of the dataset used for the recommendation system.

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
data_path = '../data/raw/dataset.csv'
df = pd.read_csv(data_path)

# Display the first few rows of the dataset
df.head()

# %% [markdown]
# ## Dataset Description
#
# The dataset consists of the following columns:
#
# - **Column 1**: Description of column 1
# - **Column 2**: Description of column 2
# - **Column 3**: Description of column 3
# - **Column 4**: Description of column 4
#
# The dataset contains a total of `n` rows and `m` columns.

# %%
# Get the shape of the dataset
df.shape
# Out:
# (n, m)

# %% [markdown]
# ## Data Types
#
# The data types of each column are as follows:

# %%
# Display data types of each column
df.dtypes
# Out:
# Column 1: data type
# Column 2: data type
# Column 3: data type
# Column 4: data type

# %% [markdown]
# ## Missing Values
#
# We will check for any missing values in the dataset.

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Column 1: missing values
# Column 2: missing values
# Column 3: missing values
# Column 4: missing values

# %% [markdown]
# ## Summary Statistics
#
# We will also provide summary statistics for the numerical columns in the dataset.

# %%
# Display summary statistics
df.describe()
# Out:
# Summary statistics output

# %% [markdown]
# ## Conclusion
#
# In this notebook, we have covered the data collection process and provided a description of the dataset. We have loaded the dataset, checked for missing values, and provided summary statistics. This information will be useful for the subsequent analysis and modeling steps.
