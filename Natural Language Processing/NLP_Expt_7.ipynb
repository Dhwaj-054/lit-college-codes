# %%
print("NLP Expt 7")
print("Dhwaj Jain S012")
# Out:
# NLP Expt 7
# Dhwaj Jain S012

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk


nltk.download('wordnet')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def get_word_relations(word):
    synonyms = set()
    hypernyms = set()
    hyponyms = set()
    antonyms = set()

    synsets = wn.synsets(word)
    if not synsets:
        return list(synonyms), list(hypernyms), list(hyponyms), list(antonyms)

    for syn in synsets:
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
            if lemma.antonyms():
                for antonym in lemma.antonyms():
                    antonyms.add(antonym.name())

        for hypernym in syn.hypernyms():
            hypernyms.add(hypernym.lemma_names()[0])
        for hyponym in syn.hyponyms():
            hyponyms.add(hyponym.lemma_names()[0])

    return list(synonyms), list(hypernyms), list(hyponyms), list(antonyms)

# %%
words = ['bank', 'bat', 'good', 'food', 'money', 'light', 'book', 'school', 'burn']

print("\n=== Word Relations ===\n")
for word in words:
    syns, hypers, hyps, ants = get_word_relations(word)
    print(f"Word: {word}")
    print(" Synonyms:", syns if syns else "None")
    print(" Hypernyms:", hypers if hypers else "None")
    print(" Hyponyms:", hyps if hyps else "None")
    print(" Antonyms:", ants if ants else "None")
    print("-" * 50)
# Out:
# === Word Relations ===
#
# Word: bank
#  Synonyms: ['cant', 'bank_building', 'savings_bank', 'money_box', 'coin_bank', 'trust', 'deposit', 'bank', 'banking_company', 'swear', 'banking_concern', 'depository_financial_institution', 'rely', 'camber']
#  Hypernyms: ['tip', 'reserve', 'slope', 'container', 'flight_maneuver', 'give', 'act', 'depository', 'enclose', 'array', 'funds', 'transact', 'believe', 'ridge', 'financial_institution', 'work', 'cover']
#  Hyponyms: ['thrift_institution', 'bluff', 'count', 'eye_bank', 'member_bank', 'blood_bank', 'credit_union', 'Federal_Reserve_Bank', 'sandbank', 'waterside', 'lead_bank', 'redeposit', 'piggy_bank', 'agent_bank', 'commercial_bank', 'riverbank', 'food_bank', 'Home_Loan_Bank', 'soil_bank', 'credit', 'acquirer', 'merchant_bank', 'lean', 'state_bank', 'vertical_bank']
#  Antonyms: ['withdraw', 'mistrust', 'distrust']
# --------------------------------------------------
# Word: bat
#  Synonyms: ['clobber', 'thrash', 'bat', 'squash_racket', 'chiropteran', 'flutter', 'drub', 'cream', 'lick', 'at-bat', 'squash_racquet', 'cricket_bat']
#  Hypernyms: ['turn', 'racket', 'placental', 'blink', 'club', 'beat', 'hit', 'cricket_equipment']
#  Hyponyms: ['paddle', 'carnivorous_bat', 'baseball_bat', 'switch-hit', 'fruit_bat']
#  Antonyms: None
# --------------------------------------------------
# Word: good
#  Synonyms: ['sound', 'expert', 'skilful', 'unspoilt', 'dependable', 'full', 'beneficial', 'adept', 'ripe', 'safe', 'well', 'skillful', 'near', 'upright', 'honest', 'goodness', 'proficient', 'dear', 'serious', 'estimable', 'effective', 'salutary', 'commodity', 'trade_good', 'good', 'thoroughly', 'secure', 'respectable', 'undecomposed', 'in_force', 'soundly', 'honorable', 'unspoiled', 'just', 'right', 'in_effect', 'practiced']
#  Hypernyms: ['artifact', 'advantage', 'morality', 'quality']
#  Hyponyms: ['entrant', 'consumer_goods', 'virtue', 'shopping', 'future', 'merchandise', 'drygoods', 'basic', 'better', 'desirability', 'wisdom', 'middling', 'fungible', 'beneficence', 'salvage', 'common_good', 'summum_bonum', 'import', 'saintliness', 'benefit', 'fancy_goods', 'sporting_goods', 'worldly_possession', 'benignity', 'optimum', 'export', 'worthiness', 'kindness']
#  Antonyms: ['evilness', 'ill', 'bad', 'evil', 'badness']
# --------------------------------------------------
# Word: food
#  Synonyms: ['food', 'food_for_thought', 'solid_food', 'intellectual_nourishment', 'nutrient']
#  Hypernyms: ['content', 'substance', 'solid']
#  Hyponyms: ['water', 'yolk', 'beverage', 'slop', 'butter', 'breakfast_food', 'leftovers', 'chyme', 'fresh_food', 'fish', 'comfort_food', 'chocolate', 'commissariat', 'feed', 'nutriment', 'coconut', 'baked_goods', 'comestible', 'meat', 'loaf', 'pabulum', 'miraculous_food', 'yogurt', 'dika_bread', 'pasta', 'foodstuff', 'convenience_food', 'produce', 'micronutrient', 'cheese', 'health_food', 'seafood', 'junk_food', 'soul_food', 'culture_medium', 'fare']
#  Antonyms: None
# --------------------------------------------------
# Word: money
#  Synonyms: ['money']
#  Hypernyms: ['medium_of_exchange', 'currency', 'wealth']
#  Hyponyms: ['boodle', 'sterling', 'subsidization', 'token_money', 'pile', 'fund', 'appropriation', 'shinplaster']
#  Antonyms: None
# --------------------------------------------------
# Word: light
#  Synonyms: ['lighting', 'lightheaded', 'idle', 'lighter', 'luminance', 'loose', 'light_source', 'dismount', 'twinkle', 'get_down', 'lightsome', 'fall', 'luminousness', 'unhorse', 'perch', 'abstemious', 'lightness', 'light', 'lite', 'sluttish', 'Light', 'visible_radiation', 'tripping', 'brightness', 'illumine', 'spark', 'brightness_level', 'Inner_Light', 'light-colored', 'clear', 'faint', 'easy', 'unaccented', 'ignite', 'visible_light', 'low-cal', 'Light_Within', 'weak', 'calorie-free', 'luminosity', 'get_off', 'short', 'wakeful', 'alight', 'light_up', 'sparkle', 'scant', 'igniter', 'illuminate', 'wanton', 'light-headed', 'lightly', 'ignitor', 'fire_up', 'illume', 'illumination', 'clean', 'swooning', 'promiscuous', 'Christ_Within', 'unclouded']
#  Hypernyms: ['vitality', 'public_knowledge', 'lighten', 'fall', 'insight', 'visual_signal', 'friend', 'descend', 'physical_property', 'position', 'ignite', 'condition', 'ethical_motive', 'source_of_illumination', 'scene', 'burn', 'visual_property', 'actinic_radiation', 'illumination', 'device', 'land', 'expression']
#  Hyponyms: ['counterglow', 'searchlight', 'scintillation', 'fuse', 'half-light', 'room_light', 'blinker', 'illuminance', 'incandescence', 'reignite', 'flood', 'kindle', 'lamplight', 'streamer', "friar's_lantern", 'traffic_light', 'match', 'beam', 'sidelight', 'brightness', 'firelight', 'daylight', 'gaslight', 'twilight', 'anchor_light', 'headlight', 'radiance', 'fluorescence', 'moonlight', 'highlight', 'torchlight', 'candlelight', 'luminescence', 'spotlight', 'glow', 'aura', 'torch', 'cigar_lighter', 'meteor', 'panel_light', 'fairy_light', 'sunniness', 'starlight', 'light_up', 'sunlight', 'corona', 'strip_lighting', 'houselights', 'flare_up', 'navigation_light', 'floodlight', 'theater_light', 'jacklight', 'sconce', 'night-light']
#  Antonyms: ['heavy', 'dark', 'extinguish']
# --------------------------------------------------
# Word: book
#  Synonyms: ['book_of_account', 'rule_book', 'script', 'Book', 'Bible', 'Word', 'hold', 'playscript', 'Scripture', 'Quran', 'Holy_Scripture', 'Holy_Writ', "al-Qur'an", 'Christian_Bible', 'ledger', 'record', 'leger', 'Koran', 'book', 'Word_of_God', 'record_book', 'reserve', 'volume', 'Good_Book', 'account_book']
#  Hypernyms: ['collection', 'section', 'dramatic_composition', 'register', 'fact', 'product', 'publication', 'request', 'sacred_text', 'schedule', 'record']
#  Hyponyms: ['bestiary', 'won-lost_record', 'daybook', 'formulary', 'order_book', 'album', 'review_copy', 'reference_book', 'storybook', 'curiosa', 'card', 'dialogue', 'catechism', 'cost_ledger', 'yearbook', 'notebook', 'paperback_book', 'folio', 'sketchbook', 'novel', 'libretto', 'tome', 'songbook', 'promptbook', 'textbook', 'shooting_script', 'subsidiary_ledger', 'hardback', 'journal', 'playbook', 'trade_book', 'picture_book', 'family_Bible', 'scenario', 'phrase_book', 'general_ledger', 'workbook', 'coffee-table_book', 'keep_open', 'prayer_book', 'logbook', 'pop-up_book', 'continuity', 'ticket', 'booklet', 'catalog', 'screenplay', 'Epistle', 'copybook', 'appointment_book', 'authority']
#  Antonyms: None
# --------------------------------------------------
# Word: school
#  Synonyms: ['shoal', 'civilize', 'school_day', 'cultivate', 'schoolhouse', 'civilise', 'educate', 'schooltime', 'schooling', 'train', 'school']
#  Hypernyms: ['building', 'education', 'educational_institution', 'swim', 'time_period', 'animal_group', 'polish', 'body', 'educate']
#  Hyponyms: ['dance_school', 'riding_school', 'veterinary_school', 'language_school', 'public_school', 'home-school', 'dancing_school', 'deconstructivism', 'finishing_school', 'alma_mater', 'Sunday_school', 'secession', 'academy', 'religious_school', 'crammer', 'driving_school', 'graduate_school', 'conservatory', 'day_school', 'flying_school', 'night_school', 'direct-grant_school', 'secretarial_school', 'secondary_school', 'sophisticate', 'private_school', 'art_nouveau', 'technical_school', 'training_school', 'nursing_school', 'pointillism', 'correspondence_school', 'grade_school', 'Ashcan_School', 'historical_school', 'lake_poets']
#  Antonyms: None
# --------------------------------------------------
# Word: burn
#  Synonyms: ['burn_up', 'combust', 'burn', 'cauterise', 'fire', 'burn_off', 'glow', 'burn_mark', 'tan', 'suntan', 'sting', 'burning', 'cut', 'bite', 'cauterize', 'sunburn', 'incinerate', 'burn_down']
#  Hypernyms: ['produce', 'destroy', 'treat', 'consume', 'change_state', 'pain', 'hyperpigmentation', 'blemish', 'injury', 'feel', 'discolor', 'damage', 'ache', 'change_integrity', 'execute', 'shine', 'waste']
#  Hyponyms: ['cigarette_burn', 'backfire', 'smolder', 'electric_burn', 'first-degree_burn', 'scald', 'flare', 'second-degree_burn', 'ignite', 'scorch', 'blaze', 'torch', 'char', 'flame', 'set_ablaze', 'cremate', 'nettle', 'third-degree_burn', 'gutter', 'deflagrate', 'burn_down']
#  Antonyms: None
# --------------------------------------------------

# %%
def lesk_wsd(sentence, target_word):
    tokens = word_tokenize(sentence.lower())
    best_synset = lesk(tokens, target_word)
    if best_synset:
        return best_synset, best_synset.definition()
    else:
        return None, None

# %%
print("-"*20 + " Word Sense Disambiguation with Lesk " + "-"*20)

sentences = [
    ("bank", "I went to the bank to deposit money."),
    ("bank", "She sat on the river bank and watched the water flow."),
    ("bat", "The cricket player swung the bat hard."),
    ("bat", "A bat flew out of the cave at night."),
    ("apple", "I bought a red apple from the market."),
    ("apple", "He updated the software on his Apple laptop."),
    ("light", "Turn on the light, it’s too dark in here."),
    ("light", "This bag is very light, I can carry it easily."),
    ("book", "She borrowed a book from the library."),
    ("book", "We need to book a hotel room for our trip."),
    ("burn", "You will need to burn that CD to view the movie."),
    ("burn", "Stop burning waste paper.")
]

for word, sent in sentences:
    tokens = word_tokenize(sent)
    sense = lesk(tokens, word)
    print(f"\nSentence: {sent}")
    if sense:
        print(f"\tPredicted Sense: {sense.name()} → {sense.definition()}")
    else:
        print("\tNo sense found.")
# Out:
# -------------------- Word Sense Disambiguation with Lesk --------------------
#
# Sentence: I went to the bank to deposit money.
# 	Predicted Sense: savings_bank.n.02 → a container (usually with a slot in the top) for keeping money at home
#
# Sentence: She sat on the river bank and watched the water flow.
# 	Predicted Sense: depository_financial_institution.n.01 → a financial institution that accepts deposits and channels the money into lending activities
#
# Sentence: The cricket player swung the bat hard.
# 	Predicted Sense: cricket_bat.n.01 → the club used in playing cricket
#
# Sentence: A bat flew out of the cave at night.
# 	Predicted Sense: bat.v.03 → have a turn at bat
#
# Sentence: I bought a red apple from the market.
# 	Predicted Sense: apple.n.01 → fruit with red or yellow or green skin and sweet to tart crisp whitish flesh
#
# Sentence: He updated the software on his Apple laptop.
# 	Predicted Sense: apple.n.02 → native Eurasian tree widely cultivated in many varieties for its firm rounded edible fruits
#
# Sentence: Turn on the light, it’s too dark in here.
# 	Predicted Sense: light.n.07 → the visual effect of illumination on objects or scenes as created in pictures
#
# Sentence: This bag is very light, I can carry it easily.
# 	Predicted Sense: luminosity.n.01 → the quality of being luminous; emitting or reflecting light
#
# Sentence: She borrowed a book from the library.
# 	Predicted Sense: record.n.05 → a compilation of the known facts regarding something or someone
#
# Sentence: We need to book a hotel room for our trip.
# 	Predicted Sense: script.n.01 → a written version of a play or other dramatic composition; used in preparing for a performance
#
# Sentence: You will need to burn that CD to view the movie.
# 	Predicted Sense: tan.n.01 → a browning of the skin resulting from exposure to the rays of the sun
#
# Sentence: Stop burning waste paper.
# 	Predicted Sense: tan.n.01 → a browning of the skin resulting from exposure to the rays of the sun

# %% [markdown]
# **Conclusion**
#
# In summary, this notebook demonstrates the use of the NLTK library for exploring word relationships such as synonyms, hypernyms, hyponyms, and antonyms using WordNet. It also showcases Word Sense Disambiguation (WSD) using the Lesk algorithm to identify the correct meaning of a word in a given sentence. The results highlight the challenges of WSD, as the Lesk algorithm didn't always select the most accurate sense for all test cases. This type of analysis is fundamental in Natural Language Processing for tasks requiring a deeper understanding of word meanings and their context.
